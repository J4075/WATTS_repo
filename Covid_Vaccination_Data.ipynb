# %% [markdown]
# <a href="https://colab.research.google.com/github/Jayjayswizzle/WATTS_repo/blob/main/Covid_Vaccination_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/vaccinations/country_data/United%20States.csv')
df
# Out:
#           location  total_vaccinations  ... people_fully_vaccinated total_boosters
# 0    United States              556208  ...                     NaN            NaN
# 1    United States              614117  ...                     NaN            NaN
# 2    United States             1008025  ...                     NaN            NaN
# 3    United States             1944585  ...                     NaN            NaN
# 4    United States             2127143  ...                     NaN            NaN
# ..             ...                 ...  ...                     ...            ...
# 225  United States           358599835  ...             169186268.0            NaN
# 226  United States           359623380  ...             169592873.0            NaN
# 227  United States           360634287  ...             169998983.0            NaN
# 228  United States           361684564  ...             170406785.0            NaN
# ...

# %%
df = df.groupby(['vaccine'])

# %%
df1 = df.loc[df['date'] >= "2021-07-18"]
df1
# Out:
#           location  total_vaccinations  ... people_fully_vaccinated total_boosters
# 194  United States           337740358  ...             161232483.0            NaN
# 195  United States           338247434  ...             161473715.0            NaN
# 196  United States           338491374  ...             161631676.0            NaN
# 197  United States           339102867  ...             161895045.0            NaN
# 198  United States           339763765  ...             162174165.0            NaN
# 199  United States           340363922  ...             162435276.0            NaN
# 200  United States           341039972  ...             162725812.0            NaN
# 201  United States           341818968  ...             163025726.0            NaN
# 202  United States           342212051  ...             163173366.0            NaN
# 203  United States           342607540  ...             163312474.0            NaN
# ...

# %%
sns.lineplot(data= df, x= "date",y= "total_vaccinations") 
plt.show()

# %%
plt.scatter(x= df1["date"],y= df1["total_vaccinations"]) 
plt.title("Last month vaccination rate")
plt.show()

# %%
df1 = df.loc[df['total_vaccinations'] == 1944585]
df1
# Out:
#         location  total_vaccinations  ... people_fully_vaccinated total_boosters
# 3  United States             1944585  ...                     NaN            NaN
#
# [1 rows x 8 columns]
